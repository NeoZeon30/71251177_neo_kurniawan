# %%
try:
    suhu = int(input("Masukkan suhu tubuh: "))

    if suhu >= 38:
        print("Anda demam")
    elif suhu <= 24:
        print("Anda kedinginan")
    else: 
        print("Anda tidak demam")
except:
    print("Error")
# Out:
# Masukkan suhu tubuh:  28
# Anda tidak demam

# %%
try:
  bil = int (input("Masukan bilangan: "))
  
  if bil > 0:
    print("Bilangan Positif")
  elif bil < 0:
    print("Bilangan Negatif")
  elif bil == 0:
    print("Bilangan Nol")
except:
  print("Error")

# %%
try:
  a = int (input("Masukan angka pertama: "))
  b = int (input("Masukan angka kedua: "))
  c = int (input("Masukan angka ketiga: "))
 
  if a > b and a > c:
    print("Angka terbesar adalah:", a)
  elif b > a and b > c:
    print("Angka terbesar adalah:", b)
  elif c > a and c > b:
    print("Angka terbesar adalah:", c)
except:
  print("Error")
